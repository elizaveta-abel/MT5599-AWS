# %% [markdown]
# # Geotagged and Mentioned

# %%
############### GEOTAGGED AND MENTIONED ####################

# get distances column from all datasets
# first determine if there are any duplicate tweet ids in there
"""
import pandas as pd
import tqdm

distances = []

for i in tqdm.tqdm(range(0, 112)):
    df = pd.read_feather("s3://mt5599/final/processed_tweets_" + str(i) + ".feather")
    
    # keep only tweets with distances
    ddf = df[pd.notnull(df.coordinates_longitude) & (df.ner_type == "LOC")].reset_index(drop=True)
    ddf.to_feather("s3://mt5599/dissertation/distances_df_" + str(i) + ".feather")
    #ddf_distance = ddf.distance
    #ddf_distance.to_feather("s3://mt5599/dissertation/distances_" + str(i) + ".feather")
    
    # new subset with only tweet duplicates
    ddf_duplicates = ddf[ddf.duplicated(subset = ["id"], keep=False)].reset_index(drop=True)
    if ddf_duplicates.shape[0] > 0:
        print("duplicates found")
        ddf_duplicates.to_feather("s3://mt5599/dissertation/duplicates_distances_df_" + str(i) + ".feather")
    
    # new subset with only not tweet duplicates
    ddf_noduplicates = ddf.drop_duplicates(subset="id", keep=False).reset_index(drop=True)
    ddf_noduplicates.to_feather("s3://mt5599/dissertation/noduplicates_distances_df_" + str(i) + ".feather")
    
"""
# Out:
# '\nimport pandas as pd\nimport tqdm\n\ndistances = []\n\nfor i in tqdm.tqdm(range(0, 112)):\n    df = pd.read_feather("s3://mt5599/final/processed_tweets_" + str(i) + ".feather")\n    \n    # keep only tweets with distances\n    ddf = df[pd.notnull(df.coordinates_longitude) & (df.ner_type == "LOC")].reset_index(drop=True)\n    ddf.to_feather("s3://mt5599/dissertation/distances_df_" + str(i) + ".feather")\n    #ddf_distance = ddf.distance\n    #ddf_distance.to_feather("s3://mt5599/dissertation/distances_" + str(i) + ".feather")\n    \n    # new subset with only tweet duplicates\n    ddf_duplicates = ddf[ddf.duplicated(subset = ["id"], keep=False)].reset_index(drop=True)\n    if ddf_duplicates.shape[0] > 0:\n        print("duplicates found")\n        ddf_duplicates.to_feather("s3://mt5599/dissertation/duplicates_distances_df_" + str(i) + ".feather")\n    \n    # new subset with only not tweet duplicates\n    ddf_noduplicates = ddf.drop_duplicates(subset="id", keep=False).reset_index(drop=True)\n    ddf_noduplicates.to_feather("s3://mt5599/dissertation/noduplicates_distances_df_" + str(i) + ".feather")\n    \n'

# %%
# combining all into one dataframe for analysis
"""
ddfs = []
ddfs_distance = []
ddfs_duplicates = []
ddfs_noduplicates = []

for i in tqdm.tqdm(range(0, 112)):
    ddf = pd.read_feather("s3://mt5599/dissertation/distances_df_" + str(i) + ".feather")
    #ddf_distance = pd.read_feather("s3://mt5599/dissertation/distances_" + str(i) + ".feather")
    ddf_duplicates = pd.read_feather("s3://mt5599/dissertation/duplicates_distances_df_" + str(i) + ".feather")
    ddf_noduplicates = pd.read_feather("s3://mt5599/dissertation/noduplicates_distances_df_" + str(i) + ".feather")
    
    ddfs.append(ddf)
    #ddfs_distance.append(ddf_distance)
    ddfs_duplicates.append(ddf_duplicates)
    ddfs_noduplicates.append(ddf_noduplicates)
    
"""
# Out:
# '\nddfs = []\nddfs_distance = []\nddfs_duplicates = []\nddfs_noduplicates = []\n\nfor i in tqdm.tqdm(range(0, 112)):\n    ddf = pd.read_feather("s3://mt5599/dissertation/distances_df_" + str(i) + ".feather")\n    #ddf_distance = pd.read_feather("s3://mt5599/dissertation/distances_" + str(i) + ".feather")\n    ddf_duplicates = pd.read_feather("s3://mt5599/dissertation/duplicates_distances_df_" + str(i) + ".feather")\n    ddf_noduplicates = pd.read_feather("s3://mt5599/dissertation/noduplicates_distances_df_" + str(i) + ".feather")\n    \n    ddfs.append(ddf)\n    #ddfs_distance.append(ddf_distance)\n    ddfs_duplicates.append(ddf_duplicates)\n    ddfs_noduplicates.append(ddf_noduplicates)\n    \n'

# %%
#ddf = pd.concat(ddfs, axis=0, ignore_index=True)
ddf.to_feather("s3://mt5599/final/distances.feather")

#ddf_distance = pd.concat(ddfs_distance, axis=0, ignore_index=True).reset_index(drop=True)
#ddf_distance.to_feather("s3://mt5599/final/distances.feather")

#ddf_duplicates = pd.concat(ddfs_duplicates, axis=0, ignore_index=True)
ddf_duplicates.to_feather("s3://mt5599/final/duplicates_distances.feather")

#ddf_noduplicates = pd.concat(ddfs_noduplicates, axis=0, ignore_index=True)
ddf_noduplicates.to_feather("s3://mt5599/final/noduplicates_distances.feather")

# %%
"""
# !pip install epiweeks
# !pip install -U kaleido

import tqdm
from multiprocessing import Pool # multithreading
from epiweeks import Week

# granularity
def granularity_helper(row):
    
    s = row[1]["gmaps_address"]
    
    # also add Epi Week processing

    #my_date = date(2018, 12, 30)
    week = Week.fromdate(row[1]["DateTime"], system="iso")
    row[1]["epi_week"] = week.cdcformat()
    
    if pd.notnull(s):
    
        split = s.split(", ")
    
        row[1]["split_address"] = split
        
        row[1]["country"] = split[-1]


        if len(split) >=5:
            row[1]["subcountry"] = split[-3]
            if any(char.isdigit() for char in split[2]) or any(char.isdigit() for char in split[1]) or any(char.isdigit() for char in split[0]):
                row[1]["granularity"] = "address"
            else:
                row[1]["granularity"] = "city/town"
                row[1]["city/town"] = split[-3]
                
        elif len(split) ==4:
            row[1]["subcountry"] = split[-3]
            if any(char.isdigit() for char in split[1]) or any(char.isdigit() for char in split[0]):
                row[1]["granularity"] = "address"
            else:
                row[1]["granularity"] = "city/town"
                row[1]["city/town"] = split[-3]
                
        elif len(split) ==3:
            row[1]["subcountry"] = split[1]
            if any(char.isdigit() for char in split[0]):
                row[1]["granularity"] = "address"
            else:
                row[1]["granularity"] = "city/town"
                row[1]["city/town"] = split[-3]
                
        elif len(split) == 2:
            row[1]["granularity"] = "subcountry"
            row[1]["subcountry"] = split[-2]
            
        elif len(split) == 1:
            row[1]["granularity"] = "country"
            

        #if len(split) >= 3:
        #    row[1]["subcountry"] = split[-3]
    
    return row[1]





def granularity(df):
    
    #df['split_address'] = None
    
    pool = Pool(processes=round(len(df.index)/10000))

    result_arr = []
    
    for result in tqdm.tqdm(pool.imap_unordered(granularity_helper, df.iterrows()),
                            total=len(df.index)):
        result_arr.append(result)
                
    df = pd.concat(result_arr, axis=1).transpose().sort_index()
                
    return df
"""

# %%
import pandas as pd

ddf = pd.read_feather("s3://mt5599/final/distances.feather")
#ddf = granularity(ddf)
ddf
# Out:
# 100%|██████████| 4061091/4061091 [26:03<00:00, 2596.73it/s]
#                          id                  DateTime  \
# 0        667792991982116864 2015-11-20 19:53:50+00:00
# 1        671492423734939648 2015-12-01 00:54:04+00:00
# 2        671493846749065216 2015-12-01 00:59:43+00:00
# 3        668271432682577920 2015-11-22 03:35:00+00:00
# 4        666014821008166912 2015-11-15 22:08:01+00:00
# ...                     ...                       ...
# 4061086  726905116083761152 2016-05-01 22:44:19+00:00
# 4061087  726895962250170368 2016-05-01 22:07:57+00:00
# 4061088  726892175850635264 2016-05-01 21:52:54+00:00
# 4061089  724364680278491136 2016-04-24 22:29:32+00:00
# 4061090  724358546779983872 2016-04-24 22:05:10+00:00
#
#                                                coordinates  \
# 0        Coordinates(longitude=-57.5548331, latitude=-3...
# 1        Coordinates(longitude=-62.889222, latitude=-34...
# 2        Coordinates(longitude=-60.2628441, latitude=-3...
# 3        Coordinates(longitude=-58.4200895, latitude=-3...
# 4        Coordinates(longitude=-58.43818626, latitude=-...
# ...                                                    ...
# 4061086  Coordinates(longitude=-56.68988656, latitude=-...
# 4061087  Coordinates(longitude=-56.68988656, latitude=-...
# 4061088  Coordinates(longitude=-56.68988656, latitude=-...
# 4061089  Coordinates(longitude=-56.68988962, latitude=-...
# 4061090  Coordinates(longitude=-56.68988962, latitude=-...
#
#                                                      place       username  \
# 0        Place(fullName='Mar del Plata, Argentina', nam...    darcena2553
# 1        Place(fullName='Santa Fe, Argentina', name='Sa...  LuchoCinqui10
# 2        Place(fullName='Buenos Aires, Argentina', name...     lucas_teti
# 3        Place(fullName='Ciudad Autónoma de Buenos Aire...     lucas_teti
# 4        Place(fullName='Ciudad Autónoma de Buenos Aire...     lucas_teti
# ...                                                    ...            ...
# 4061086  Place(fullName='La Costa, Argentina', name='La...       ludmi526
# 4061087  Place(fullName='La Costa, Argentina', name='La...       ludmi526
# 4061088  Place(fullName='La Costa, Argentina', name='La...       ludmi526
# 4061089  Place(fullName='La Costa, Argentina', name='La...       ludmi526
# 4061090  Place(fullName='La Costa, Argentina', name='La...       ludmi526
#
#             user_id               user_location  \
# 0        2358639522  No soy unica soy diferente
# 1        3914185529
# 2        1535237646                   Argentina
# 3        1535237646                   Argentina
# 4        1535237646                   Argentina
# ...             ...                         ...
# 4061086  3224699505         La Costa, Argentina
# 4061087  3224699505         La Costa, Argentina
# 4061088  3224699505         La Costa, Argentina
# 4061089  3224699505         La Costa, Argentina
# 4061090  3224699505         La Costa, Argentina
#
#                                              tweet_content lang  \
# 0                       #Acuopolis https://t.co/9Wa5WQmezz  qme
# 1        @HDF_ESPN Saludos desde Santa Fe Galvez Muy Bu...   es
# 2        no dudo que se va a repetir este viaje, herman...   es
# 3        feo asado te mandaste flaqui 👌 @ Club Geba Pal...   es
# 4        Con la mejor mesera de pani 🍰🎂 @ Pani Palermo ...   es
# ...                                                    ...  ...
# 4061086  Domingggo @ Santa Teresita La Costa https://t....   it
# 4061087  Domingogo. @ Santa Teresita La Costa https://t...   it
# 4061088  Muuuy Domingo. @ Santa Teresita La Costa https...   es
# 4061089  Una de anoche. @ Santa Teresita La Costa https...   es
# 4061090  I need you. @ Santa Teresita La Costa https://...   it
#
#                                                tweet_clean  ...  gmaps_lat  \
# 0                                               Acuopolis   ...  40.456663
# 1         Saludos desde Santa Fe Galvez Muy Buen Progra...  ...  35.686975
# 2        no dudo que se va a repetir este viaje, herman...  ... -24.782127
# 3        feo asado te mandaste flaqui @ Club Geba Palermo   ...   38.11569
# 4        Con la mejor mesera de pani @ Pani Palermo Cas...  ...   38.11569
# ...                                                    ...  ...        ...
# 4061086               Domingggo @ Santa Teresita La Costa   ... -36.544051
# 4061087              Domingogo. @ Santa Teresita La Costa   ... -36.544051
# 4061088          Muuuy Domingo. @ Santa Teresita La Costa   ... -36.544051
# 4061089          Una de anoche. @ Santa Teresita La Costa   ... -36.544051
# 4061090             I need you. @ Santa Teresita La Costa   ... -36.544051
#
#          gmaps_long                                      gmaps_address  \
# 0         -3.990413  Av. Dehesa, s/n, 28691 Villanueva de la Cañada...
# 1       -105.937799                                  Santa Fe, NM, USA
# 2        -65.423198                   Salta, Salta Province, Argentina
# 3         13.361487                                 Palermo, PA, Italy
# 4         13.361487                                 Palermo, PA, Italy
# ...             ...                                                ...
# 4061086  -56.690393   Santa Teresita, Buenos Aires Province, Argentina
# 4061087  -56.690393   Santa Teresita, Buenos Aires Province, Argentina
# 4061088  -56.690393   Santa Teresita, Buenos Aires Province, Argentina
# 4061089  -56.690393   Santa Teresita, Buenos Aires Province, Argentina
# 4061090  -56.690393   Santa Teresita, Buenos Aires Province, Argentina
#
#              distance epi_week  \
# 0        10263.000004   201547
# 1         8954.693094   201549
# 2         1166.637753   201549
# 3        10933.542601   201547
# 4        10935.524726   201546
# ...               ...      ...
# 4061086      0.569563   201617
# 4061087      0.569563   201617
# 4061088      0.569563   201617
# 4061089      0.570435   201616
# 4061090      0.570435   201616
#
#                                              split_address    country  \
# 0        [Av. Dehesa, s/n, 28691 Villanueva de la Cañad...      Spain
# 1                                      [Santa Fe, NM, USA]        USA
# 2                       [Salta, Salta Province, Argentina]  Argentina
# 3                                     [Palermo, PA, Italy]      Italy
# 4                                     [Palermo, PA, Italy]      Italy
# ...                                                    ...        ...
# 4061086  [Santa Teresita, Buenos Aires Province, Argent...  Argentina
# 4061087  [Santa Teresita, Buenos Aires Province, Argent...  Argentina
# 4061088  [Santa Teresita, Buenos Aires Province, Argent...  Argentina
# 4061089  [Santa Teresita, Buenos Aires Province, Argent...  Argentina
# 4061090  [Santa Teresita, Buenos Aires Province, Argent...  Argentina
#
#                             subcountry granularity       city/town
# 0        28691 Villanueva de la Cañada     address             NaN
# 1                                   NM   city/town        Santa Fe
# 2                       Salta Province   city/town           Salta
# 3                                   PA   city/town         Palermo
# 4                                   PA   city/town         Palermo
# ...                                ...         ...             ...
# 4061086          Buenos Aires Province   city/town  Santa Teresita
# 4061087          Buenos Aires Province   city/town  Santa Teresita
# 4061088          Buenos Aires Province   city/town  Santa Teresita
# 4061089          Buenos Aires Province   city/town  Santa Teresita
# 4061090          Buenos Aires Province   city/town  Santa Teresita
#
# [4061091 rows x 29 columns]

# %%
ddf.distance.value_counts(dropna=False)
# Out:
# NaN             1830856
# 631.541213        72409
# 0.928182          24636
# 631.568807        23516
# 615.992548        22782
#                  ...
# 176.204687            1
# 6092.859194           1
# 52.069561             1
# 4442.634509           1
# 10081.119339          1
# Name: distance, Length: 370214, dtype: int64

# %%
ddf.columns
# Out:
# Index(['id', 'DateTime', 'coordinates', 'place', 'username', 'user_id',
#        'user_location', 'tweet_content', 'lang', 'tweet_clean',
#        'place_full_name', 'place_name', 'place_type', 'place_country',
#        'place_country_code', 'coordinates_longitude', 'coordinates_latitude',
#        'ner_type', 'ner_word', 'gmaps_lat', 'gmaps_long', 'gmaps_address',
#        'distance', 'epi_week', 'split_address', 'country', 'subcountry',
#        'granularity', 'city/town'],
#       dtype='object')

# %%
ddf_duplicates = pd.read_feather("s3://mt5599/final/duplicates_distances.feather")
#ddf_duplicates = granularity(ddf_duplicates)
ddf_duplicates
# Out:
# 100%|██████████| 1833947/1833947 [12:15<00:00, 2493.73it/s]
#                          id                  DateTime  \
# 0        663545043203026944 2015-11-09 02:34:01+00:00
# 1        663545043203026944 2015-11-09 02:34:01+00:00
# 2        757745528755068928 2016-07-26 01:13:06+00:00
# 3        757745528755068928 2016-07-26 01:13:06+00:00
# 4        751568029083799552 2016-07-09 00:05:56+00:00
# ...                     ...                       ...
# 1833942  772571186261811200 2016-09-04 23:04:59+00:00
# 1833943  772571186261811200 2016-09-04 23:04:59+00:00
# 1833944  772571186261811200 2016-09-04 23:04:59+00:00
# 1833945  754824112686690304 2016-07-17 23:44:27+00:00
# 1833946  754824112686690304 2016-07-17 23:44:27+00:00
#
#                                                coordinates  \
# 0        Coordinates(longitude=-58.39055556, latitude=-...
# 1        Coordinates(longitude=-58.39055556, latitude=-...
# 2        Coordinates(longitude=-58.8495591, latitude=-2...
# 3        Coordinates(longitude=-58.8495591, latitude=-2...
# 4        Coordinates(longitude=-58.8333, latitude=-27.4...
# ...                                                    ...
# 1833942  Coordinates(longitude=-58.23846306, latitude=-...
# 1833943  Coordinates(longitude=-58.23846306, latitude=-...
# 1833944  Coordinates(longitude=-58.23846306, latitude=-...
# 1833945  Coordinates(longitude=-58.41049505, latitude=-...
# 1833946  Coordinates(longitude=-58.41049505, latitude=-...
#
#                                                      place    username  \
# 0        Place(fullName='Ciudad Autónoma de Buenos Aire...  lucas_teti
# 1        Place(fullName='Ciudad Autónoma de Buenos Aire...  lucas_teti
# 2        Place(fullName='Corrientes, Argentina', name='...  diegocraig
# 3        Place(fullName='Corrientes, Argentina', name='...  diegocraig
# 4        Place(fullName='Corrientes, Argentina', name='...  diegocraig
# ...                                                    ...         ...
# 1833942  Place(fullName='Quilmes, Argentina', name='Qui...    ludmi526
# 1833943  Place(fullName='Quilmes, Argentina', name='Qui...    ludmi526
# 1833944  Place(fullName='Quilmes, Argentina', name='Qui...    ludmi526
# 1833945  Place(fullName='Ciudad Autónoma de Buenos Aire...    ludmi526
# 1833946  Place(fullName='Ciudad Autónoma de Buenos Aire...    ludmi526
#
#             user_id          user_location  \
# 0        1535237646              Argentina
# 1        1535237646              Argentina
# 2          35910512  Corrientes, Argentina
# 3          35910512  Corrientes, Argentina
# 4          35910512  Corrientes, Argentina
# ...             ...                    ...
# 1833942  3224699505    La Costa, Argentina
# 1833943  3224699505    La Costa, Argentina
# 1833944  3224699505    La Costa, Argentina
# 1833945  3224699505    La Costa, Argentina
# 1833946  3224699505    La Costa, Argentina
#
#                                              tweet_content lang  \
# 0        De festejo con el mejor 🔞 @ Recoleta, Buenos A...   es
# 1        De festejo con el mejor 🔞 @ Recoleta, Buenos A...   es
# 2        #prismacolors #prisma #Corrientes #argentina @...   es
# 3        #prismacolors #prisma #Corrientes #argentina @...   es
# 4        #drone del #bicentenario @ Corrientes, Argenti...   es
# ...                                                    ...  ...
# 1833942  ☀☀ @ Autopista Bs As - La Plata https://t.co/I...   es
# 1833943  ☀☀ @ Autopista Bs As - La Plata https://t.co/I...   es
# 1833944  ☀☀ @ Autopista Bs As - La Plata https://t.co/I...   es
# 1833945  💎 @ Barrio De Palermo , Buenos Aires Argentina...   es
# 1833946  💎 @ Barrio De Palermo , Buenos Aires Argentina...   es
#
#                                                tweet_clean  ...  gmaps_lat  \
# 0        De festejo con el mejor @ Recoleta, Buenos Aires   ... -34.587382
# 1        De festejo con el mejor @ Recoleta, Buenos Aires   ... -34.603684
# 2         prismacolors prisma Corrientes argentina @ Co...  ...  -28.58416
# 3         prismacolors prisma Corrientes argentina @ Co...  ... -27.469213
# 4          drone del bicentenario @ Corrientes, Argentina   ...  -28.58416
# ...                                                    ...  ...        ...
# 1833942                      @ Autopista Bs As - La Plata   ...        NaN
# 1833943                      @ Autopista Bs As - La Plata   ...        NaN
# 1833944                      @ Autopista Bs As - La Plata   ... -34.920495
# 1833945      @ Barrio De Palermo , Buenos Aires Argentina   ... -34.578066
# 1833946      @ Barrio De Palermo , Buenos Aires Argentina   ... -34.603684
#
#         gmaps_long                               gmaps_address   distance  \
# 0       -58.397276           Recoleta, Buenos Aires, Argentina    0.70997
# 1       -58.381559                     Buenos Aires, Argentina   1.673993
# 2       -58.007192                       Corrientes, Argentina  148.54326
# 3       -58.830635                       Corrientes, Argentina   1.887685
# 4       -58.007192                       Corrientes, Argentina  148.10407
# ...            ...                                         ...        ...
# 1833942        NaN                                        None        NaN
# 1833943        NaN                                        None        NaN
# 1833944 -57.953566  La Plata, Buenos Aires Province, Argentina  34.506358
# 1833945 -58.426532            Palermo, Buenos Aires, Argentina   1.874618
# 1833946 -58.381559                     Buenos Aires, Argentina   3.141592
#
#         epi_week                                 split_address    country  \
# 0         201546           [Recoleta, Buenos Aires, Argentina]  Argentina
# 1         201546                     [Buenos Aires, Argentina]  Argentina
# 2         201630                       [Corrientes, Argentina]  Argentina
# 3         201630                       [Corrientes, Argentina]  Argentina
# 4         201627                       [Corrientes, Argentina]  Argentina
# ...          ...                                           ...        ...
# 1833942   201635                                           NaN        NaN
# 1833943   201635                                           NaN        NaN
# 1833944   201635  [La Plata, Buenos Aires Province, Argentina]  Argentina
# 1833945   201628            [Palermo, Buenos Aires, Argentina]  Argentina
# 1833946   201628                     [Buenos Aires, Argentina]  Argentina
#
#         granularity             subcountry city/town
# 0         city/town           Buenos Aires  Recoleta
# 1        subcountry           Buenos Aires       NaN
# 2        subcountry             Corrientes       NaN
# 3        subcountry             Corrientes       NaN
# 4        subcountry             Corrientes       NaN
# ...             ...                    ...       ...
# 1833942         NaN                    NaN       NaN
# 1833943         NaN                    NaN       NaN
# 1833944   city/town  Buenos Aires Province  La Plata
# 1833945   city/town           Buenos Aires   Palermo
# 1833946  subcountry           Buenos Aires       NaN
#
# [1833947 rows x 29 columns]

# %%
ddf_noduplicates = pd.read_feather("s3://mt5599/final/noduplicates_distances.feather")
#ddf_noduplicates = granularity(ddf_noduplicates)
ddf_noduplicates
# Out:
# 100%|██████████| 2227144/2227144 [14:58<00:00, 2479.35it/s]
#                          id                  DateTime  \
# 0        667792991982116864 2015-11-20 19:53:50+00:00
# 1        671492423734939648 2015-12-01 00:54:04+00:00
# 2        671493846749065216 2015-12-01 00:59:43+00:00
# 3        668271432682577920 2015-11-22 03:35:00+00:00
# 4        666014821008166912 2015-11-15 22:08:01+00:00
# ...                     ...                       ...
# 2227139  726905116083761152 2016-05-01 22:44:19+00:00
# 2227140  726895962250170368 2016-05-01 22:07:57+00:00
# 2227141  726892175850635264 2016-05-01 21:52:54+00:00
# 2227142  724364680278491136 2016-04-24 22:29:32+00:00
# 2227143  724358546779983872 2016-04-24 22:05:10+00:00
#
#                                                coordinates  \
# 0        Coordinates(longitude=-57.5548331, latitude=-3...
# 1        Coordinates(longitude=-62.889222, latitude=-34...
# 2        Coordinates(longitude=-60.2628441, latitude=-3...
# 3        Coordinates(longitude=-58.4200895, latitude=-3...
# 4        Coordinates(longitude=-58.43818626, latitude=-...
# ...                                                    ...
# 2227139  Coordinates(longitude=-56.68988656, latitude=-...
# 2227140  Coordinates(longitude=-56.68988656, latitude=-...
# 2227141  Coordinates(longitude=-56.68988656, latitude=-...
# 2227142  Coordinates(longitude=-56.68988962, latitude=-...
# 2227143  Coordinates(longitude=-56.68988962, latitude=-...
#
#                                                      place       username  \
# 0        Place(fullName='Mar del Plata, Argentina', nam...    darcena2553
# 1        Place(fullName='Santa Fe, Argentina', name='Sa...  LuchoCinqui10
# 2        Place(fullName='Buenos Aires, Argentina', name...     lucas_teti
# 3        Place(fullName='Ciudad Autónoma de Buenos Aire...     lucas_teti
# 4        Place(fullName='Ciudad Autónoma de Buenos Aire...     lucas_teti
# ...                                                    ...            ...
# 2227139  Place(fullName='La Costa, Argentina', name='La...       ludmi526
# 2227140  Place(fullName='La Costa, Argentina', name='La...       ludmi526
# 2227141  Place(fullName='La Costa, Argentina', name='La...       ludmi526
# 2227142  Place(fullName='La Costa, Argentina', name='La...       ludmi526
# 2227143  Place(fullName='La Costa, Argentina', name='La...       ludmi526
#
#             user_id               user_location  \
# 0        2358639522  No soy unica soy diferente
# 1        3914185529
# 2        1535237646                   Argentina
# 3        1535237646                   Argentina
# 4        1535237646                   Argentina
# ...             ...                         ...
# 2227139  3224699505         La Costa, Argentina
# 2227140  3224699505         La Costa, Argentina
# 2227141  3224699505         La Costa, Argentina
# 2227142  3224699505         La Costa, Argentina
# 2227143  3224699505         La Costa, Argentina
#
#                                              tweet_content lang  \
# 0                       #Acuopolis https://t.co/9Wa5WQmezz  qme
# 1        @HDF_ESPN Saludos desde Santa Fe Galvez Muy Bu...   es
# 2        no dudo que se va a repetir este viaje, herman...   es
# 3        feo asado te mandaste flaqui 👌 @ Club Geba Pal...   es
# 4        Con la mejor mesera de pani 🍰🎂 @ Pani Palermo ...   es
# ...                                                    ...  ...
# 2227139  Domingggo @ Santa Teresita La Costa https://t....   it
# 2227140  Domingogo. @ Santa Teresita La Costa https://t...   it
# 2227141  Muuuy Domingo. @ Santa Teresita La Costa https...   es
# 2227142  Una de anoche. @ Santa Teresita La Costa https...   es
# 2227143  I need you. @ Santa Teresita La Costa https://...   it
#
#                                                tweet_clean  ...  gmaps_lat  \
# 0                                               Acuopolis   ...  40.456663
# 1         Saludos desde Santa Fe Galvez Muy Buen Progra...  ...  35.686975
# 2        no dudo que se va a repetir este viaje, herman...  ... -24.782127
# 3        feo asado te mandaste flaqui @ Club Geba Palermo   ...   38.11569
# 4        Con la mejor mesera de pani @ Pani Palermo Cas...  ...   38.11569
# ...                                                    ...  ...        ...
# 2227139               Domingggo @ Santa Teresita La Costa   ... -36.544051
# 2227140              Domingogo. @ Santa Teresita La Costa   ... -36.544051
# 2227141          Muuuy Domingo. @ Santa Teresita La Costa   ... -36.544051
# 2227142          Una de anoche. @ Santa Teresita La Costa   ... -36.544051
# 2227143             I need you. @ Santa Teresita La Costa   ... -36.544051
#
#          gmaps_long                                      gmaps_address  \
# 0         -3.990413  Av. Dehesa, s/n, 28691 Villanueva de la Cañada...
# 1       -105.937799                                  Santa Fe, NM, USA
# 2        -65.423198                   Salta, Salta Province, Argentina
# 3         13.361487                                 Palermo, PA, Italy
# 4         13.361487                                 Palermo, PA, Italy
# ...             ...                                                ...
# 2227139  -56.690393   Santa Teresita, Buenos Aires Province, Argentina
# 2227140  -56.690393   Santa Teresita, Buenos Aires Province, Argentina
# 2227141  -56.690393   Santa Teresita, Buenos Aires Province, Argentina
# 2227142  -56.690393   Santa Teresita, Buenos Aires Province, Argentina
# 2227143  -56.690393   Santa Teresita, Buenos Aires Province, Argentina
#
#              distance epi_week  \
# 0        10263.000004   201547
# 1         8954.693094   201549
# 2         1166.637753   201549
# 3        10933.542601   201547
# 4        10935.524726   201546
# ...               ...      ...
# 2227139      0.569563   201617
# 2227140      0.569563   201617
# 2227141      0.569563   201617
# 2227142      0.570435   201616
# 2227143      0.570435   201616
#
#                                              split_address    country  \
# 0        [Av. Dehesa, s/n, 28691 Villanueva de la Cañad...      Spain
# 1                                      [Santa Fe, NM, USA]        USA
# 2                       [Salta, Salta Province, Argentina]  Argentina
# 3                                     [Palermo, PA, Italy]      Italy
# 4                                     [Palermo, PA, Italy]      Italy
# ...                                                    ...        ...
# 2227139  [Santa Teresita, Buenos Aires Province, Argent...  Argentina
# 2227140  [Santa Teresita, Buenos Aires Province, Argent...  Argentina
# 2227141  [Santa Teresita, Buenos Aires Province, Argent...  Argentina
# 2227142  [Santa Teresita, Buenos Aires Province, Argent...  Argentina
# 2227143  [Santa Teresita, Buenos Aires Province, Argent...  Argentina
#
#         granularity                     subcountry       city/town
# 0           address  28691 Villanueva de la Cañada             NaN
# 1         city/town                             NM        Santa Fe
# 2         city/town                 Salta Province           Salta
# 3         city/town                             PA         Palermo
# 4         city/town                             PA         Palermo
# ...             ...                            ...             ...
# 2227139   city/town          Buenos Aires Province  Santa Teresita
# 2227140   city/town          Buenos Aires Province  Santa Teresita
# 2227141   city/town          Buenos Aires Province  Santa Teresita
# 2227142   city/town          Buenos Aires Province  Santa Teresita
# 2227143   city/town          Buenos Aires Province  Santa Teresita
#
# [2227144 rows x 29 columns]

# %% [markdown]
# # Basic Statistics

# %%
# Overall

import numpy as np

nandistance = ddf.loc[ddf.distance >= 0, "distance"]
nandup = ddf_duplicates.loc[ddf_duplicates.distance >= 0, "distance"]
nannodup = ddf_noduplicates.loc[ddf_noduplicates.distance >= 0, "distance"]

print("median: ",
      round(np.median(nandistance), 2),
      round(np.median(nandup), 2),
      round(np.median(nannodup), 2))
print("mean: ",
      round(np.mean(nandistance), 2),
      round(np.mean(nandup), 2),
      round(np.mean(nannodup), 2))

# AUC

# plot distribution of distances

# 50km is the furthest Cordoba spreads, and most of the time it is 15km

# accuracy at .1
print("accuracy@0.1: ",
      round(nandistance[nandistance <= .1].shape[0]/nandistance.shape[0], 3),
      round(nandup[nandup <= .1].shape[0]/nandup.shape[0], 3),
      round(nannodup[nannodup <= .1].shape[0]/nannodup.shape[0], 3))

# accuracy at .5
print("accuracy@0.5: ",
      round(nandistance[nandistance <= .5].shape[0]/nandistance.shape[0], 3),
      round(nandup[nandup <= .5].shape[0]/nandup.shape[0], 3),
      round(nannodup[nannodup <= .5].shape[0]/nannodup.shape[0], 3))

# accuracy at 1
print("accuracy@1: ",
      round(nandistance[nandistance <= 1].shape[0]/nandistance.shape[0], 3),
      round(nandup[nandup <= 1].shape[0]/nandup.shape[0], 3),
      round(nannodup[nannodup <= 1].shape[0]/nannodup.shape[0], 3))

# accuracy at 5
print("accuracy@5: ",
      round(nandistance[nandistance <= 5].shape[0]/nandistance.shape[0], 3),
      round(nandup[nandup <= 5].shape[0]/nandup.shape[0], 3),
      round(nannodup[nannodup <= 5].shape[0]/nannodup.shape[0], 3))

# accuracy at 10
print("accuracy@10: ",
      round(nandistance[nandistance <= 10].shape[0]/nandistance.shape[0], 3),
      round(nandup[nandup <= 10].shape[0]/nandup.shape[0], 3),
      round(nannodup[nannodup <= 10].shape[0]/nannodup.shape[0], 3))

# accuracy at 10
print("accuracy@25: ",
      round(nandistance[nandistance <= 25].shape[0]/nandistance.shape[0], 3),
      round(nandup[nandup <= 25].shape[0]/nandup.shape[0], 3),
      round(nannodup[nannodup <= 25].shape[0]/nannodup.shape[0], 3))

# accuracy at 50
print("accuracy@50: ",
      round(nandistance[nandistance <= 50].shape[0]/nandistance.shape[0], 3),
      round(nandup[nandup <= 50].shape[0]/nandup.shape[0], 3),
      round(nannodup[nannodup <= 50].shape[0]/nannodup.shape[0], 3))

# accuracy at 100
print("accuracy@100: ",
      round(nandistance[nandistance <= 100].shape[0]/nandistance.shape[0], 3),
      round(nandup[nandup <= 100].shape[0]/nandup.shape[0], 3),
      round(nannodup[nannodup <= 100].shape[0]/nannodup.shape[0], 3))

# accuracy at 161
print("accuracy@161: ",
      round(nandistance[nandistance <= 161].shape[0]/nandistance.shape[0], 3),
      round(nandup[nandup <= 161].shape[0]/nandup.shape[0], 3),
      round(nannodup[nannodup <= 161].shape[0]/nannodup.shape[0], 3))

# accuracy at 1000
print("accuracy@1000: ",
      round(nandistance[nandistance <= 1000].shape[0]/nandistance.shape[0], 3),
      round(nandup[nandup <= 1000].shape[0]/nandup.shape[0], 3),
      round(nannodup[nannodup <= 1000].shape[0]/nannodup.shape[0], 3))
# Out:
# median:  479.11 142.58 631.54
# mean:  2708.79 1977.22 3477.69
# accuracy@0.1:  0.031 0.033 0.028
# accuracy@0.5:  0.074 0.08 0.066
# accuracy@1:  0.132 0.14 0.124
# accuracy@5:  0.254 0.306 0.2
# accuracy@10:  0.297 0.358 0.233
# accuracy@25:  0.358 0.421 0.292
# accuracy@50:  0.38 0.45 0.307
# accuracy@100:  0.404 0.484 0.321
# accuracy@161:  0.427 0.516 0.333
# accuracy@1000:  0.67 0.74 0.597

# %%
t1 = ddf.drop_duplicates(["id"])
t1
# Out:
#                          id                  DateTime  \
# 0        667792991982116864 2015-11-20 19:53:50+00:00
# 1        671492423734939648 2015-12-01 00:54:04+00:00
# 2        671493846749065216 2015-12-01 00:59:43+00:00
# 3        668271432682577920 2015-11-22 03:35:00+00:00
# 4        666014821008166912 2015-11-15 22:08:01+00:00
# ...                     ...                       ...
# 4061086  726905116083761152 2016-05-01 22:44:19+00:00
# 4061087  726895962250170368 2016-05-01 22:07:57+00:00
# 4061088  726892175850635264 2016-05-01 21:52:54+00:00
# 4061089  724364680278491136 2016-04-24 22:29:32+00:00
# 4061090  724358546779983872 2016-04-24 22:05:10+00:00
#
#                                                coordinates  \
# 0        Coordinates(longitude=-57.5548331, latitude=-3...
# 1        Coordinates(longitude=-62.889222, latitude=-34...
# 2        Coordinates(longitude=-60.2628441, latitude=-3...
# 3        Coordinates(longitude=-58.4200895, latitude=-3...
# 4        Coordinates(longitude=-58.43818626, latitude=-...
# ...                                                    ...
# 4061086  Coordinates(longitude=-56.68988656, latitude=-...
# 4061087  Coordinates(longitude=-56.68988656, latitude=-...
# 4061088  Coordinates(longitude=-56.68988656, latitude=-...
# 4061089  Coordinates(longitude=-56.68988962, latitude=-...
# 4061090  Coordinates(longitude=-56.68988962, latitude=-...
#
#                                                      place       username  \
# 0        Place(fullName='Mar del Plata, Argentina', nam...    darcena2553
# 1        Place(fullName='Santa Fe, Argentina', name='Sa...  LuchoCinqui10
# 2        Place(fullName='Buenos Aires, Argentina', name...     lucas_teti
# 3        Place(fullName='Ciudad Autónoma de Buenos Aire...     lucas_teti
# 4        Place(fullName='Ciudad Autónoma de Buenos Aire...     lucas_teti
# ...                                                    ...            ...
# 4061086  Place(fullName='La Costa, Argentina', name='La...       ludmi526
# 4061087  Place(fullName='La Costa, Argentina', name='La...       ludmi526
# 4061088  Place(fullName='La Costa, Argentina', name='La...       ludmi526
# 4061089  Place(fullName='La Costa, Argentina', name='La...       ludmi526
# 4061090  Place(fullName='La Costa, Argentina', name='La...       ludmi526
#
#             user_id               user_location  \
# 0        2358639522  No soy unica soy diferente
# 1        3914185529
# 2        1535237646                   Argentina
# 3        1535237646                   Argentina
# 4        1535237646                   Argentina
# ...             ...                         ...
# 4061086  3224699505         La Costa, Argentina
# 4061087  3224699505         La Costa, Argentina
# 4061088  3224699505         La Costa, Argentina
# 4061089  3224699505         La Costa, Argentina
# 4061090  3224699505         La Costa, Argentina
#
#                                              tweet_content lang  \
# 0                       #Acuopolis https://t.co/9Wa5WQmezz  qme
# 1        @HDF_ESPN Saludos desde Santa Fe Galvez Muy Bu...   es
# 2        no dudo que se va a repetir este viaje, herman...   es
# 3        feo asado te mandaste flaqui 👌 @ Club Geba Pal...   es
# 4        Con la mejor mesera de pani 🍰🎂 @ Pani Palermo ...   es
# ...                                                    ...  ...
# 4061086  Domingggo @ Santa Teresita La Costa https://t....   it
# 4061087  Domingogo. @ Santa Teresita La Costa https://t...   it
# 4061088  Muuuy Domingo. @ Santa Teresita La Costa https...   es
# 4061089  Una de anoche. @ Santa Teresita La Costa https...   es
# 4061090  I need you. @ Santa Teresita La Costa https://...   it
#
#                                                tweet_clean  ...  gmaps_lat  \
# 0                                               Acuopolis   ...  40.456663
# 1         Saludos desde Santa Fe Galvez Muy Buen Progra...  ...  35.686975
# 2        no dudo que se va a repetir este viaje, herman...  ... -24.782127
# 3        feo asado te mandaste flaqui @ Club Geba Palermo   ...   38.11569
# 4        Con la mejor mesera de pani @ Pani Palermo Cas...  ...   38.11569
# ...                                                    ...  ...        ...
# 4061086               Domingggo @ Santa Teresita La Costa   ... -36.544051
# 4061087              Domingogo. @ Santa Teresita La Costa   ... -36.544051
# 4061088          Muuuy Domingo. @ Santa Teresita La Costa   ... -36.544051
# 4061089          Una de anoche. @ Santa Teresita La Costa   ... -36.544051
# 4061090             I need you. @ Santa Teresita La Costa   ... -36.544051
#
#          gmaps_long                                      gmaps_address  \
# 0         -3.990413  Av. Dehesa, s/n, 28691 Villanueva de la Cañada...
# 1       -105.937799                                  Santa Fe, NM, USA
# 2        -65.423198                   Salta, Salta Province, Argentina
# 3         13.361487                                 Palermo, PA, Italy
# 4         13.361487                                 Palermo, PA, Italy
# ...             ...                                                ...
# 4061086  -56.690393   Santa Teresita, Buenos Aires Province, Argentina
# 4061087  -56.690393   Santa Teresita, Buenos Aires Province, Argentina
# 4061088  -56.690393   Santa Teresita, Buenos Aires Province, Argentina
# 4061089  -56.690393   Santa Teresita, Buenos Aires Province, Argentina
# 4061090  -56.690393   Santa Teresita, Buenos Aires Province, Argentina
#
#              distance epi_week  \
# 0        10263.000004   201547
# 1         8954.693094   201549
# 2         1166.637753   201549
# 3        10933.542601   201547
# 4        10935.524726   201546
# ...               ...      ...
# 4061086      0.569563   201617
# 4061087      0.569563   201617
# 4061088      0.569563   201617
# 4061089      0.570435   201616
# 4061090      0.570435   201616
#
#                                              split_address    country  \
# 0        [Av. Dehesa, s/n, 28691 Villanueva de la Cañad...      Spain
# 1                                      [Santa Fe, NM, USA]        USA
# 2                       [Salta, Salta Province, Argentina]  Argentina
# 3                                     [Palermo, PA, Italy]      Italy
# 4                                     [Palermo, PA, Italy]      Italy
# ...                                                    ...        ...
# 4061086  [Santa Teresita, Buenos Aires Province, Argent...  Argentina
# 4061087  [Santa Teresita, Buenos Aires Province, Argent...  Argentina
# 4061088  [Santa Teresita, Buenos Aires Province, Argent...  Argentina
# 4061089  [Santa Teresita, Buenos Aires Province, Argent...  Argentina
# 4061090  [Santa Teresita, Buenos Aires Province, Argent...  Argentina
#
#                             subcountry granularity       city/town
# 0        28691 Villanueva de la Cañada     address             NaN
# 1                                   NM   city/town        Santa Fe
# 2                       Salta Province   city/town           Salta
# 3                                   PA   city/town         Palermo
# 4                                   PA   city/town         Palermo
# ...                                ...         ...             ...
# 4061086          Buenos Aires Province   city/town  Santa Teresita
# 4061087          Buenos Aires Province   city/town  Santa Teresita
# 4061088          Buenos Aires Province   city/town  Santa Teresita
# 4061089          Buenos Aires Province   city/town  Santa Teresita
# 4061090          Buenos Aires Province   city/town  Santa Teresita
#
# [3015837 rows x 29 columns]

# %%
t2 = ddf[pd.notnull(ddf.country)].drop_duplicates(["id"])
t2
# Out:
#                          id                  DateTime  \
# 0        667792991982116864 2015-11-20 19:53:50+00:00
# 1        671492423734939648 2015-12-01 00:54:04+00:00
# 2        671493846749065216 2015-12-01 00:59:43+00:00
# 3        668271432682577920 2015-11-22 03:35:00+00:00
# 4        666014821008166912 2015-11-15 22:08:01+00:00
# ...                     ...                       ...
# 4061086  726905116083761152 2016-05-01 22:44:19+00:00
# 4061087  726895962250170368 2016-05-01 22:07:57+00:00
# 4061088  726892175850635264 2016-05-01 21:52:54+00:00
# 4061089  724364680278491136 2016-04-24 22:29:32+00:00
# 4061090  724358546779983872 2016-04-24 22:05:10+00:00
#
#                                                coordinates  \
# 0        Coordinates(longitude=-57.5548331, latitude=-3...
# 1        Coordinates(longitude=-62.889222, latitude=-34...
# 2        Coordinates(longitude=-60.2628441, latitude=-3...
# 3        Coordinates(longitude=-58.4200895, latitude=-3...
# 4        Coordinates(longitude=-58.43818626, latitude=-...
# ...                                                    ...
# 4061086  Coordinates(longitude=-56.68988656, latitude=-...
# 4061087  Coordinates(longitude=-56.68988656, latitude=-...
# 4061088  Coordinates(longitude=-56.68988656, latitude=-...
# 4061089  Coordinates(longitude=-56.68988962, latitude=-...
# 4061090  Coordinates(longitude=-56.68988962, latitude=-...
#
#                                                      place       username  \
# 0        Place(fullName='Mar del Plata, Argentina', nam...    darcena2553
# 1        Place(fullName='Santa Fe, Argentina', name='Sa...  LuchoCinqui10
# 2        Place(fullName='Buenos Aires, Argentina', name...     lucas_teti
# 3        Place(fullName='Ciudad Autónoma de Buenos Aire...     lucas_teti
# 4        Place(fullName='Ciudad Autónoma de Buenos Aire...     lucas_teti
# ...                                                    ...            ...
# 4061086  Place(fullName='La Costa, Argentina', name='La...       ludmi526
# 4061087  Place(fullName='La Costa, Argentina', name='La...       ludmi526
# 4061088  Place(fullName='La Costa, Argentina', name='La...       ludmi526
# 4061089  Place(fullName='La Costa, Argentina', name='La...       ludmi526
# 4061090  Place(fullName='La Costa, Argentina', name='La...       ludmi526
#
#             user_id               user_location  \
# 0        2358639522  No soy unica soy diferente
# 1        3914185529
# 2        1535237646                   Argentina
# 3        1535237646                   Argentina
# 4        1535237646                   Argentina
# ...             ...                         ...
# 4061086  3224699505         La Costa, Argentina
# 4061087  3224699505         La Costa, Argentina
# 4061088  3224699505         La Costa, Argentina
# 4061089  3224699505         La Costa, Argentina
# 4061090  3224699505         La Costa, Argentina
#
#                                              tweet_content lang  \
# 0                       #Acuopolis https://t.co/9Wa5WQmezz  qme
# 1        @HDF_ESPN Saludos desde Santa Fe Galvez Muy Bu...   es
# 2        no dudo que se va a repetir este viaje, herman...   es
# 3        feo asado te mandaste flaqui 👌 @ Club Geba Pal...   es
# 4        Con la mejor mesera de pani 🍰🎂 @ Pani Palermo ...   es
# ...                                                    ...  ...
# 4061086  Domingggo @ Santa Teresita La Costa https://t....   it
# 4061087  Domingogo. @ Santa Teresita La Costa https://t...   it
# 4061088  Muuuy Domingo. @ Santa Teresita La Costa https...   es
# 4061089  Una de anoche. @ Santa Teresita La Costa https...   es
# 4061090  I need you. @ Santa Teresita La Costa https://...   it
#
#                                                tweet_clean  ...  gmaps_lat  \
# 0                                               Acuopolis   ...  40.456663
# 1         Saludos desde Santa Fe Galvez Muy Buen Progra...  ...  35.686975
# 2        no dudo que se va a repetir este viaje, herman...  ... -24.782127
# 3        feo asado te mandaste flaqui @ Club Geba Palermo   ...   38.11569
# 4        Con la mejor mesera de pani @ Pani Palermo Cas...  ...   38.11569
# ...                                                    ...  ...        ...
# 4061086               Domingggo @ Santa Teresita La Costa   ... -36.544051
# 4061087              Domingogo. @ Santa Teresita La Costa   ... -36.544051
# 4061088          Muuuy Domingo. @ Santa Teresita La Costa   ... -36.544051
# 4061089          Una de anoche. @ Santa Teresita La Costa   ... -36.544051
# 4061090             I need you. @ Santa Teresita La Costa   ... -36.544051
#
#          gmaps_long                                      gmaps_address  \
# 0         -3.990413  Av. Dehesa, s/n, 28691 Villanueva de la Cañada...
# 1       -105.937799                                  Santa Fe, NM, USA
# 2        -65.423198                   Salta, Salta Province, Argentina
# 3         13.361487                                 Palermo, PA, Italy
# 4         13.361487                                 Palermo, PA, Italy
# ...             ...                                                ...
# 4061086  -56.690393   Santa Teresita, Buenos Aires Province, Argentina
# 4061087  -56.690393   Santa Teresita, Buenos Aires Province, Argentina
# 4061088  -56.690393   Santa Teresita, Buenos Aires Province, Argentina
# 4061089  -56.690393   Santa Teresita, Buenos Aires Province, Argentina
# 4061090  -56.690393   Santa Teresita, Buenos Aires Province, Argentina
#
#              distance epi_week  \
# 0        10263.000004   201547
# 1         8954.693094   201549
# 2         1166.637753   201549
# 3        10933.542601   201547
# 4        10935.524726   201546
# ...               ...      ...
# 4061086      0.569563   201617
# 4061087      0.569563   201617
# 4061088      0.569563   201617
# 4061089      0.570435   201616
# 4061090      0.570435   201616
#
#                                              split_address    country  \
# 0        [Av. Dehesa, s/n, 28691 Villanueva de la Cañad...      Spain
# 1                                      [Santa Fe, NM, USA]        USA
# 2                       [Salta, Salta Province, Argentina]  Argentina
# 3                                     [Palermo, PA, Italy]      Italy
# 4                                     [Palermo, PA, Italy]      Italy
# ...                                                    ...        ...
# 4061086  [Santa Teresita, Buenos Aires Province, Argent...  Argentina
# 4061087  [Santa Teresita, Buenos Aires Province, Argent...  Argentina
# 4061088  [Santa Teresita, Buenos Aires Province, Argent...  Argentina
# 4061089  [Santa Teresita, Buenos Aires Province, Argent...  Argentina
# 4061090  [Santa Teresita, Buenos Aires Province, Argent...  Argentina
#
#                             subcountry granularity       city/town
# 0        28691 Villanueva de la Cañada     address             NaN
# 1                                   NM   city/town        Santa Fe
# 2                       Salta Province   city/town           Salta
# 3                                   PA   city/town         Palermo
# 4                                   PA   city/town         Palermo
# ...                                ...         ...             ...
# 4061086          Buenos Aires Province   city/town  Santa Teresita
# 4061087          Buenos Aires Province   city/town  Santa Teresita
# 4061088          Buenos Aires Province   city/town  Santa Teresita
# 4061089          Buenos Aires Province   city/town  Santa Teresita
# 4061090          Buenos Aires Province   city/town  Santa Teresita
#
# [1722811 rows x 29 columns]

# %%
print("There are ", t1.shape[0], " tweets that have both a geotag and a LOC mention (",
      len(t1.username.unique())," users).\n",
     "Of those, ", t2.shape[0], " tweets have a geotag and geoparsed location (",
    len(t2.username.unique())," users).\n")
# Out:
# There are  3015837  tweets that have both a geotag and a LOC mention ( 82342  users).
#  Of those,  1722811  tweets have a geotag and geoparsed location ( 72898  users).

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set figure size and style
sns.set(rc={'figure.figsize':(10,7)})
sns.set_style(style={'axes.edgecolor': 'black', 'axes.facecolor': 'white'})

fig, axes = plt.subplots(3, 1)
fig.suptitle('Distribution of Distances')

# Plot the density plot of the "distance" column
sns.kdeplot(data = nandistance, cut=0, bw=50, shade=True, color="green", ax=axes[0], label="All Tweets")
            #ddf['distance'],
             #color='black', kde=False)
sns.kdeplot(data = ddf_duplicates['distance'], cut=0, bw=50, shade=True, color="blue", ax=axes[1], label="Tweets with Multiple LOC Mentions")
            #ddf['distance'],
             #color='black', kde=False)

sns.kdeplot(data = ddf_noduplicates['distance'], cut=0, bw=50, shade=True, color="red", ax=axes[2], label="Tweets with One LOC Mention")
            #ddf['distance'],
             #color='black', kde=False)


# Rename axis labels

#plt.ylabel('Density')
#plt.xlabel('Distance (km)')

fig.text(0.5, 0.01, 'Number of Tweets', ha='center')
fig.text(0.01, 0.5, 'Frequency', va='center', rotation='vertical')

#fig.set(xlabel='Density', ylabel='Distance (km)')

plt.savefig('distance_frequency.png')
plt.show()

# %%
"""
import seaborn as sns
import matplotlib.pyplot as plt

# Set figure size and style
sns.set(rc={'figure.figsize':(10,7)})
sns.set_style(style={'axes.edgecolor': 'black', 'axes.facecolor': 'white'})

# Plot the density plot of the "distance" column from ddf_duplicates
sns.distplot(ddf_duplicates['distance'], color='blue', label='Duplicates', kde=False)

# Plot the density plot of the "distance" column from ddf_noduplicates
sns.distplot(ddf_noduplicates['distance'], color='red', label='No Duplicates', kde=False)

# Rename axis labels
plt.xlabel('Distance (km)')
plt.ylabel('Density')

# Add legend
plt.legend()
plt.savefig('distance_dup_frequency.png')
plt.show()
"""

# %% [markdown]
# # How many times do countries match?

# %%
# check if country names are the same
gdf = ddf[pd.notnull(ddf.country)]
mentioned = gdf.country.value_counts(dropna=False).rename_axis('country').reset_index(name='mentioned')
mentioned
# Out:
#               country  mentioned
# 0           Argentina    1333231
# 1                 USA     250803
# 2              Brazil      66076
# 3               Chile      50790
# 4               Spain      41092
# ..                ...        ...
# 440          Caucasus          1
# 441          Kiribati          1
# 442             Rhône          1
# 443  Singapore 699014          1
# 444            558004          1
#
# [445 rows x 2 columns]

# %%
gdf.loc[ddf.place_country == "United States", "place_country"] = "USA"
geotagged = gdf.place_country.value_counts(dropna=False).rename_axis('country').reset_index(name='geotagged')
geotagged
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#                             country  geotagged
# 0                         Argentina    1950798
# 1                               USA      71929
# 2                            Brazil      34746
# 3                               NaN      29212
# 4                             Chile      27139
# ..                              ...        ...
# 196        Turks and Caicos Islands          1
# 197           Saint Kitts and Nevis          1
# 198  Federated States of Micronesia          1
# 199                           Tonga          1
# 200                          Gambia          1
#
# [201 rows x 2 columns]

# %%
merged = geotagged.merge(mentioned, how="inner", on="country")

# %%
merged.geotagged.sum()
# Out:
# 2193081

# %%
merged.mentioned.sum()
# Out:
# 2112000

# %%
import numpy as np

mask = np.where(gdf.place_country == gdf.country, True, False)
matching_countries = gdf[mask]

# %%
matching_countries_ = matching_countries.drop_duplicates(["id"])

# %%
print("Of the ", t2.shape[0], " tweets with both a geotag and a geoparsed location, \n",
     matching_countries_.shape[0], " tweets have at least one matching country.\n\n",
     "Considering the duplicate mentions too, of the ",ddf[pd.notnull(ddf.country)].shape[0],
      " mentioned location countries\n",
      matching_countries.shape[0], " corresponded with the geotagged country.")
# Out:
# Of the  1722811  tweets with both a geotag and a geoparsed location,
#  1190520  tweets have at least one matching country.
#
#  Considering the duplicate mentions too, of the  2230235  mentioned location countries
#  1512941  corresponded with the geotagged country.

# %% [markdown]
# # -- Epi Week -- | -- Username -- | -- Mentioned -- | -- Geotagged --

# %%
df = ddf[pd.notnull(ddf.country)]
df
# Out:
#                          id                  DateTime  \
# 0        667792991982116864 2015-11-20 19:53:50+00:00
# 1        671492423734939648 2015-12-01 00:54:04+00:00
# 2        671493846749065216 2015-12-01 00:59:43+00:00
# 3        668271432682577920 2015-11-22 03:35:00+00:00
# 4        666014821008166912 2015-11-15 22:08:01+00:00
# ...                     ...                       ...
# 4061086  726905116083761152 2016-05-01 22:44:19+00:00
# 4061087  726895962250170368 2016-05-01 22:07:57+00:00
# 4061088  726892175850635264 2016-05-01 21:52:54+00:00
# 4061089  724364680278491136 2016-04-24 22:29:32+00:00
# 4061090  724358546779983872 2016-04-24 22:05:10+00:00
#
#                                                coordinates  \
# 0        Coordinates(longitude=-57.5548331, latitude=-3...
# 1        Coordinates(longitude=-62.889222, latitude=-34...
# 2        Coordinates(longitude=-60.2628441, latitude=-3...
# 3        Coordinates(longitude=-58.4200895, latitude=-3...
# 4        Coordinates(longitude=-58.43818626, latitude=-...
# ...                                                    ...
# 4061086  Coordinates(longitude=-56.68988656, latitude=-...
# 4061087  Coordinates(longitude=-56.68988656, latitude=-...
# 4061088  Coordinates(longitude=-56.68988656, latitude=-...
# 4061089  Coordinates(longitude=-56.68988962, latitude=-...
# 4061090  Coordinates(longitude=-56.68988962, latitude=-...
#
#                                                      place       username  \
# 0        Place(fullName='Mar del Plata, Argentina', nam...    darcena2553
# 1        Place(fullName='Santa Fe, Argentina', name='Sa...  LuchoCinqui10
# 2        Place(fullName='Buenos Aires, Argentina', name...     lucas_teti
# 3        Place(fullName='Ciudad Autónoma de Buenos Aire...     lucas_teti
# 4        Place(fullName='Ciudad Autónoma de Buenos Aire...     lucas_teti
# ...                                                    ...            ...
# 4061086  Place(fullName='La Costa, Argentina', name='La...       ludmi526
# 4061087  Place(fullName='La Costa, Argentina', name='La...       ludmi526
# 4061088  Place(fullName='La Costa, Argentina', name='La...       ludmi526
# 4061089  Place(fullName='La Costa, Argentina', name='La...       ludmi526
# 4061090  Place(fullName='La Costa, Argentina', name='La...       ludmi526
#
#             user_id               user_location  \
# 0        2358639522  No soy unica soy diferente
# 1        3914185529
# 2        1535237646                   Argentina
# 3        1535237646                   Argentina
# 4        1535237646                   Argentina
# ...             ...                         ...
# 4061086  3224699505         La Costa, Argentina
# 4061087  3224699505         La Costa, Argentina
# 4061088  3224699505         La Costa, Argentina
# 4061089  3224699505         La Costa, Argentina
# 4061090  3224699505         La Costa, Argentina
#
#                                              tweet_content lang  \
# 0                       #Acuopolis https://t.co/9Wa5WQmezz  qme
# 1        @HDF_ESPN Saludos desde Santa Fe Galvez Muy Bu...   es
# 2        no dudo que se va a repetir este viaje, herman...   es
# 3        feo asado te mandaste flaqui 👌 @ Club Geba Pal...   es
# 4        Con la mejor mesera de pani 🍰🎂 @ Pani Palermo ...   es
# ...                                                    ...  ...
# 4061086  Domingggo @ Santa Teresita La Costa https://t....   it
# 4061087  Domingogo. @ Santa Teresita La Costa https://t...   it
# 4061088  Muuuy Domingo. @ Santa Teresita La Costa https...   es
# 4061089  Una de anoche. @ Santa Teresita La Costa https...   es
# 4061090  I need you. @ Santa Teresita La Costa https://...   it
#
#                                                tweet_clean  ...  gmaps_lat  \
# 0                                               Acuopolis   ...  40.456663
# 1         Saludos desde Santa Fe Galvez Muy Buen Progra...  ...  35.686975
# 2        no dudo que se va a repetir este viaje, herman...  ... -24.782127
# 3        feo asado te mandaste flaqui @ Club Geba Palermo   ...   38.11569
# 4        Con la mejor mesera de pani @ Pani Palermo Cas...  ...   38.11569
# ...                                                    ...  ...        ...
# 4061086               Domingggo @ Santa Teresita La Costa   ... -36.544051
# 4061087              Domingogo. @ Santa Teresita La Costa   ... -36.544051
# 4061088          Muuuy Domingo. @ Santa Teresita La Costa   ... -36.544051
# 4061089          Una de anoche. @ Santa Teresita La Costa   ... -36.544051
# 4061090             I need you. @ Santa Teresita La Costa   ... -36.544051
#
#          gmaps_long                                      gmaps_address  \
# 0         -3.990413  Av. Dehesa, s/n, 28691 Villanueva de la Cañada...
# 1       -105.937799                                  Santa Fe, NM, USA
# 2        -65.423198                   Salta, Salta Province, Argentina
# 3         13.361487                                 Palermo, PA, Italy
# 4         13.361487                                 Palermo, PA, Italy
# ...             ...                                                ...
# 4061086  -56.690393   Santa Teresita, Buenos Aires Province, Argentina
# 4061087  -56.690393   Santa Teresita, Buenos Aires Province, Argentina
# 4061088  -56.690393   Santa Teresita, Buenos Aires Province, Argentina
# 4061089  -56.690393   Santa Teresita, Buenos Aires Province, Argentina
# 4061090  -56.690393   Santa Teresita, Buenos Aires Province, Argentina
#
#              distance epi_week  \
# 0        10263.000004   201547
# 1         8954.693094   201549
# 2         1166.637753   201549
# 3        10933.542601   201547
# 4        10935.524726   201546
# ...               ...      ...
# 4061086      0.569563   201617
# 4061087      0.569563   201617
# 4061088      0.569563   201617
# 4061089      0.570435   201616
# 4061090      0.570435   201616
#
#                                              split_address    country  \
# 0        [Av. Dehesa, s/n, 28691 Villanueva de la Cañad...      Spain
# 1                                      [Santa Fe, NM, USA]        USA
# 2                       [Salta, Salta Province, Argentina]  Argentina
# 3                                     [Palermo, PA, Italy]      Italy
# 4                                     [Palermo, PA, Italy]      Italy
# ...                                                    ...        ...
# 4061086  [Santa Teresita, Buenos Aires Province, Argent...  Argentina
# 4061087  [Santa Teresita, Buenos Aires Province, Argent...  Argentina
# 4061088  [Santa Teresita, Buenos Aires Province, Argent...  Argentina
# 4061089  [Santa Teresita, Buenos Aires Province, Argent...  Argentina
# 4061090  [Santa Teresita, Buenos Aires Province, Argent...  Argentina
#
#                             subcountry granularity       city/town
# 0        28691 Villanueva de la Cañada     address             NaN
# 1                                   NM   city/town        Santa Fe
# 2                       Salta Province   city/town           Salta
# 3                                   PA   city/town         Palermo
# 4                                   PA   city/town         Palermo
# ...                                ...         ...             ...
# 4061086          Buenos Aires Province   city/town  Santa Teresita
# 4061087          Buenos Aires Province   city/town  Santa Teresita
# 4061088          Buenos Aires Province   city/town  Santa Teresita
# 4061089          Buenos Aires Province   city/town  Santa Teresita
# 4061090          Buenos Aires Province   city/town  Santa Teresita
#
# [2230235 rows x 29 columns]

# %%
mentioned = ddf.groupby(['username', "epi_week"])["country"].unique().reset_index(name='countries')
geotagged = ddf.groupby(['username', "epi_week"])["place_country"].unique().reset_index(name='countries')

# %%
user_countries = mentioned.countries.tolist()
all_countries = pd.DataFrame({"counts":list(itertools.chain.from_iterable(user_countries))})
temp = pd.DataFrame(all_countries.counts.value_counts()).reset_index().rename({"index": "place"}, axis=1)
temp
