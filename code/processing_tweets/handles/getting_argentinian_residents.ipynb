# %%
import boto3
import pandas as pd
from sagemaker import get_execution_role

role = get_execution_role()
bucket='mt5599'
df_2016 = 'df_2016.csv'
df_2019 = 'df_2019.csv'
data_location_2016 = 's3://{}/{}'.format(bucket, df_2016)
data_location_2019 = 's3://{}/{}'.format(bucket, df_2019)

df_2016 = pd.read_csv(data_location_2016)
df_2019 = pd.read_csv(data_location_2019)
# Out:
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3553: DtypeWarning: Columns (27) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         Unnamed: 0                                                url  \
# 0                0  https://twitter.com/KenobiCDM/status/114548213...
# 1                1  https://twitter.com/jopa94/status/114548175292...
# 2                2  https://twitter.com/KenobiCDM/status/114548139...
# 3                3  https://twitter.com/wongsterb/status/114548122...
# 4                4  https://twitter.com/carlushin/status/114548058...
# ...            ...                                                ...
# 229517      229517  https://twitter.com/JaviTico95cr/status/126724...
# 229518      229518  https://twitter.com/monseg97/status/1267245523...
# 229519      229519  https://twitter.com/rofonck/status/12672449195...
# 229520      229520  https://twitter.com/_Ale21/status/126724491480...
# 229521      229521  https://twitter.com/JaviTico95cr/status/126724...
#
#                              date  \
# 0       2019-06-30 23:59:58+00:00
# 1       2019-06-30 23:58:26+00:00
# 2       2019-06-30 23:57:00+00:00
# 3       2019-06-30 23:56:20+00:00
# 4       2019-06-30 23:53:47+00:00
# ...                           ...
# 229517  2020-06-01 00:05:17+00:00
# 229518  2020-06-01 00:04:11+00:00
# 229519  2020-06-01 00:01:47+00:00
# 229520  2020-06-01 00:01:46+00:00
# 229521  2020-06-01 00:01:42+00:00
#
#                                                   content  \
# 0       @AcunaCabrera Me parece adecuado aplicar las p...
# 1       Listos 🤪🤪🤪 (@ Grill And Chill in Puntarenas) h...
# 2                                       @adardon96 JAJAJA
# 3       @jroiz29 @fuckingescapist @_Overkiller Si, si ...
# 4       @LaQueAja Si tienes netflix te recomiendo The ...
# ...                                                   ...
# 229517  Guzmán es central de Saprissa eso es roja o pe...
# 229518  Esto era lo que me faltaba, que ganas de pegar...
# 229519  Señor TU que estás en los cielos, recibe mi or...
# 229520                                    VAMOS LIGA! 🔴⚫️
# 229521                  ¡Vamos Liga! \nHay que ganar \n🔴⚫
#
#                                           renderedContent  \
# 0       @AcunaCabrera Me parece adecuado aplicar las p...
# 1       Listos 🤪🤪🤪 (@ Grill And Chill in Puntarenas) s...
# 2                                       @adardon96 JAJAJA
# 3       @jroiz29 @fuckingescapist @_Overkiller Si, si ...
# 4       @LaQueAja Si tienes netflix te recomiendo The ...
# ...                                                   ...
# 229517  Guzmán es central de Saprissa eso es roja o pe...
# 229518  Esto era lo que me faltaba, que ganas de pegar...
# 229519  Señor TU que estás en los cielos, recibe mi or...
# 229520                                    VAMOS LIGA! 🔴⚫️
# 229521                  ¡Vamos Liga! \nHay que ganar \n🔴⚫
#
#                          id  \
# 0       1145482138873188352
# 1       1145481752921694209
# 2       1145481390332502016
# 3       1145481222992408576
# 4       1145480580605386758
# ...                     ...
# 229517  1267245798749810695
# 229518  1267245523205046272
# 229519  1267244919586017282
# 229520  1267244914808627206
# 229521  1267244896005640193
#
#                                                      user  replyCount  \
# 0       {'username': 'KenobiCDM', 'id': 289195546, 'di...           0
# 1       {'username': 'jopa94', 'id': 950301631, 'displ...           0
# 2       {'username': 'KenobiCDM', 'id': 289195546, 'di...           0
# 3       {'username': 'wongsterb', 'id': 191150814, 'di...           1
# 4       {'username': 'carlushin', 'id': 51296772, 'dis...           1
# ...                                                   ...         ...
# 229517  {'username': 'JaviTico95cr', 'id': 77844697170...           0
# 229518  {'username': 'monseg97', 'id': 221869643, 'dis...           0
# 229519  {'username': 'rofonck', 'id': 193567663, 'disp...           0
# 229520  {'username': '_Ale21', 'id': 228287652, 'displ...           0
# 229521  {'username': 'JaviTico95cr', 'id': 77844697170...           0
#
#         retweetCount  likeCount  ...  user_statuses_count  \
# 0                  0          0  ...                 2891
# 1                  0          0  ...                13018
# 2                  0          1  ...                 2891
# 3                  0          1  ...                44449
# 4                  0          2  ...                56579
# ...              ...        ...  ...                  ...
# 229517             0          1  ...                26935
# 229518             0          0  ...                36989
# 229519             0          0  ...                  100
# 229520             2          1  ...               102248
# 229521             0          0  ...                26935
#
#         user_favourites_count user_listed_count user_media_count  \
# 0                       30343                 0              416
# 1                       11292                 0              875
# 2                       30343                 0              416
# 3                       30918                32             2596
# 4                       44058                10              612
# ...                       ...               ...              ...
# 229517                 126686                29              330
# 229518                  30857                 0              642
# 229519                    618                 0                5
# 229520                  28972                13             4114
# 229521                 126686                29              330
#
#        user_protected                                      user_link_url  \
# 0               False        http://www.facebook.com/carlos.delgado.9275
# 1               False                                               None
# 2               False        http://www.facebook.com/carlos.delgado.9275
# 3               False  https://open.spotify.com/artist/0w1vMiSn8wVzs0...
# 4               False                                               None
# ...               ...                                                ...
# 229517          False                                               None
# 229518          False                                               None
# 229519          False                                               None
# 229520          False                                               None
# 229521          False                                               None
#
#                     link_tcourl  \
# 0       https://t.co/1ybcxnl1Gw
# 1                          None
# 2       https://t.co/1ybcxnl1Gw
# 3       https://t.co/33avEZ3whi
# 4                          None
# ...                         ...
# 229517                     None
# 229518                     None
# 229519                     None
# 229520                     None
# 229521                     None
#
#                                    user_profile_image_url  \
# 0       https://pbs.twimg.com/profile_images/136533664...
# 1       https://pbs.twimg.com/profile_images/153152161...
# 2       https://pbs.twimg.com/profile_images/136533664...
# 3       https://pbs.twimg.com/profile_images/157440842...
# 4       https://pbs.twimg.com/profile_images/135716338...
# ...                                                   ...
# 229517  https://pbs.twimg.com/profile_images/148801126...
# 229518  https://pbs.twimg.com/profile_images/137810188...
# 229519  https://pbs.twimg.com/profile_images/148620639...
# 229520  https://pbs.twimg.com/profile_images/157608093...
# 229521  https://pbs.twimg.com/profile_images/148801126...
#
#                                   user_profile_banner_url  user_label
# 0       https://pbs.twimg.com/profile_banners/28919554...        None
# 1       https://pbs.twimg.com/profile_banners/95030163...        None
# 2       https://pbs.twimg.com/profile_banners/28919554...        None
# 3       https://pbs.twimg.com/profile_banners/19115081...        None
# 4       https://pbs.twimg.com/profile_banners/51296772...        None
# ...                                                   ...         ...
# 229517  https://pbs.twimg.com/profile_banners/77844697...        None
# 229518  https://pbs.twimg.com/profile_banners/22186964...        None
# 229519  https://pbs.twimg.com/profile_banners/19356766...        None
# 229520  https://pbs.twimg.com/profile_banners/22828765...        None
# 229521  https://pbs.twimg.com/profile_banners/77844697...        None
#
# [229522 rows x 48 columns]

# %%
import boto3

bucket='mt5599'

boto3.Session().resource('s3').Bucket(bucket).Object('df_2016.csv').upload_file('../../data/df_2016.csv')

# %%
import numpy as np

exp = "AR"

df_2016['Place_Flag'] = np.where(df_2016['place'].str.contains(exp, case=False, na=False), 'T', '')

df_2016.Place_Flag.value_counts(dropna=False)

# %%
import numpy as np

exp = "AR"

df_2019['Place_Flag'] = np.where(df_2019['place'].str.contains(exp, case=False, na=False), 'T', '')

df_2019.Place_Flag.value_counts(dropna=False)

# %%
place_df_2016 = df_2016[df_2016.Place_Flag == 'T']
place_df_2019 = df_2019[df_2019.Place_Flag == 'T']

# %%
place_usernames_2016 = place_df_2016.username.unique()
place_usernames_2019 = place_df_2019.username.unique()

# %%
import tqdm

place_username_proportions_2016 = dict()

for username in tqdm.tqdm(place_usernames):
    if df_2016[(df_2016.username == username)].shape[0] >=10:
        tweets_in_argentina = df_2016[(df_2016.username == username) & (df_2016.Place_Flag == 'T')].shape[0]
        total_tweets = df_2016[(df_2016.username == username)].shape[0]
        proportion_of_tweets = tweets_in_argentina/total_tweets
        place_username_proportions_2016[username] = proportion_of_tweets
place_username_proportions_2016

# %%
import tqdm

place_username_proportions_2019 = dict()

for username in tqdm.tqdm(place_usernames):
    if df_2019[(df_2019.username == username)].shape[0] >=10:
        tweets_in_argentina = df_2019[(df_2019.username == username) & (df_2019.Place_Flag == 'T')].shape[0]
        total_tweets = df_2019[(df_2019.username == username)].shape[0]
        proportion_of_tweets = tweets_in_argentina/total_tweets
        place_username_proportions_2019[username] = proportion_of_tweets
place_username_proportions_2019

# %%
d_2016 = dict((k, v) for k, v in place_username_proportions_2016.items() if v >= 0.3)
d_2019 = dict((k, v) for k, v in place_username_proportions_2019.items() if v >= 0.3)

# %%
sum(place_username_proportions_2016.values()) / len(place_username_proportions_2016)

# %%
sum(place_username_proportions_2019.values()) / len(place_username_proportions_2019)

# %%
sum(d_2016.values()) / len(d_2016)

# %%
sum(d_2019.values()) / len(d_2019)

# %%
len(d_2016)

# %%
len(place_username_proportions_2019)

# %%
with open("../../data/argentina_residents_by_place_2016.txt", "w") as f:
    for handle, v in d_2016.items():
        f.write(f"{handle}\n")

# %%
with open("../../data/argentina_residents_by_place_2019.txt", "w") as f:
    for handle, v in d_2019.items():
        f.write(f"{handle}\n")

# %%
not_cr = df_2019[df_2019.user_location.str.contains("costa|rica|cr", case=False, na=False) == False]
not_cr

# %%
pd.set_option('display.max_rows', None)

not_cr.user_location.value_counts(dropna=False)

# %%
import numpy as np

exp = """argentina|Buenos Aires|Almirante Brown|Bahía Blanca|Caseros|Ezeiza|General San Martín|Junín|Lanús|La Plata|Lomas de Zamora|Luján|Lujan|Mar del Plata|Merlo|Morón|Moron|Olivos|Pergamino|Quilmes|San Isidro|San Justo|San Nicolás de los Arroyos|San Nicolas de los Arroyos|Tandil|Tigre|Zárate|Zarate|Catamarca|Catamarca|Chaco|Resistencia|Ciudad de Buenos Aires|Chubut|Comodoro Rivadavia|Rawson|Córdoba|Córdoba|Río Cuarto|Rio Cuarto|Villa María|Villa Maria|Corrientes|Entre Ríos|Entre Rios|Concepción del Uruguay|Concepcion del Uruguay|Concordia|Gualeguaychú|Gualeguaychu|Paraná|Parana|Formosa|Formosa|Jujuy|San Salvador de Jujuy|Mendoza|Godoy Cruz|Mendoza|San Rafael|Villa Nueva|Misiones|Posadas|Neuquén|Neuquén|La Pampa|Santa Rosa|La Rioja|Río Negro|Rio Negro|San Carlos de Bariloche|Viedma|Salta|San Juan|San Juan|San Luis|Mercedes|San Luis|Santa Cruz|Río Gallegos|Santa Fe|Rosario|San Lorenzo|Santa Fe|Santiago del Estero|Santiago del Estero|Tierra del Fuego|Ushuaia|Tucumán|Tucuman|San Miguel de Tucumán"""

df_2016['Argentina_Flag'] = np.where(df_2016['user_location'].str.contains(exp, case=False, na=False), 'T', '')

df_2016.Argentina_Flag.value_counts(dropna=False)

# %%
location_username_2016 = df_2016.loc[df_2016.Argentina_Flag == 'T', "username"].unique()

# %%
import numpy as np

exp = """argentina|Buenos Aires|Almirante Brown|Bahía Blanca|Caseros|Ezeiza|General San Martín|Junín|Lanús|La Plata|Lomas de Zamora|Luján|Lujan|Mar del Plata|Merlo|Morón|Moron|Olivos|Pergamino|Quilmes|San Isidro|San Justo|San Nicolás de los Arroyos|San Nicolas de los Arroyos|Tandil|Tigre|Zárate|Zarate|Catamarca|Catamarca|Chaco|Resistencia|Ciudad de Buenos Aires|Chubut|Comodoro Rivadavia|Rawson|Córdoba|Córdoba|Río Cuarto|Rio Cuarto|Villa María|Villa Maria|Corrientes|Entre Ríos|Entre Rios|Concepción del Uruguay|Concepcion del Uruguay|Concordia|Gualeguaychú|Gualeguaychu|Paraná|Parana|Formosa|Formosa|Jujuy|San Salvador de Jujuy|Mendoza|Godoy Cruz|Mendoza|San Rafael|Villa Nueva|Misiones|Posadas|Neuquén|Neuquén|La Pampa|Santa Rosa|La Rioja|Río Negro|Rio Negro|San Carlos de Bariloche|Viedma|Salta|San Juan|San Juan|San Luis|Mercedes|San Luis|Santa Cruz|Río Gallegos|Santa Fe|Rosario|San Lorenzo|Santa Fe|Santiago del Estero|Santiago del Estero|Tierra del Fuego|Ushuaia|Tucumán|Tucuman|San Miguel de Tucumán"""

df_2019['Argentina_Flag'] = np.where(df_2019['user_location'].str.contains(exp, case=False, na=False), 'T', '')

df_2019.Argentina_Flag.value_counts(dropna=False)

# %%
location_username_2019 = df_2019.loc[df_2019.Argentina_Flag == 'T', "username"].unique()

# %%
len(location_username_2016)

# %%
with open("../../data/argentina_residents_by_user_location_2016.txt", "w") as f:
    for handle in location_username_2016:
        f.write(f"{handle}\n")

# %%
with open("../../data/argentina_residents_by_user_location_2019.txt", "w") as f:
    for handle in location_username_2019:
        f.write(f"{handle}\n")
