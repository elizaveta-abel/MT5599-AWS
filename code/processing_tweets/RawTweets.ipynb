# %%
import boto3

bucket='mt5599'

boto3.Session().resource('s3').Bucket(bucket).Object('tweets_location_2016.csv').upload_file('../data/tweets_location_2016.csv')
boto3.Session().resource('s3').Bucket(bucket).Object('tweets_location_2019.csv').upload_file('../data/tweets_location_2016.csv')
boto3.Session().resource('s3').Bucket(bucket).Object('tweets_place_2016.csv').upload_file('../data/tweets_place_2016.csv')
boto3.Session().resource('s3').Bucket(bucket).Object('tweets_place_2019.csv').upload_file('../data/tweets_place_2019.csv')

# %%
import pandas as pd

location_2016 = pd.read_json("../data/tweets_location_2016.json")
location_2016
# Out:
#                         id                  DateTime  \
# 0       730389934725435392 2016-05-11 13:31:45+00:00
# 1       660279130944966656 2015-10-31 02:16:26+00:00
# 2       789943838982938624 2016-10-22 21:37:42+00:00
# 3       788900004840759296 2016-10-20 00:29:52+00:00
# 4       787459033720561664 2016-10-16 01:03:58+00:00
# ...                    ...                       ...
# 385346  649386213825187840 2015-10-01 00:51:53+00:00
# 385347  649385678376181760 2015-10-01 00:49:45+00:00
# 385348  649382780556734464 2015-10-01 00:38:14+00:00
# 385349  649382712801918976 2015-10-01 00:37:58+00:00
# 385350  649379116643430400 2015-10-01 00:23:40+00:00
#
#                                             tweet_content cashtags  \
# 0              @PLNSanisidro @lissvil @plncr @JuventudPLN     None
# 1                                Confie en la experiencia     None
# 2       Arrancó @themagicnumbers #PersonalFest 🎉🙋🏻#Fel...     None
# ...

# %%
import pandas as pd

place_2016_1 = pd.read_json("../data/tweets_place_2016_1.json")
place_2016_1
# Out:
#                          id                  DateTime  \
# 0        784384243497480192 2016-10-07 13:25:51+00:00
# 1        784383799857602560 2016-10-07 13:24:05+00:00
# 2        784381984541855744 2016-10-07 13:16:52+00:00
# 3        784381773182414848 2016-10-07 13:16:02+00:00
# 4        784379568484261888 2016-10-07 13:07:16+00:00
# ...                     ...                       ...
# 1047239  649408674499182592 2015-10-01 02:21:08+00:00
# 1047240  649408440582860800 2015-10-01 02:20:12+00:00
# 1047241  649408215294214144 2015-10-01 02:19:18+00:00
# 1047242  649380691898073088 2015-10-01 00:29:56+00:00
# 1047243  649380624143224832 2015-10-01 00:29:40+00:00
#
#                                              tweet_content cashtags  \
# 0        @cartagadascr @marioredondo @MrHRScr lo que es...     None
# 1        @MrHRScr @marioredondo @cartagadascr yo la con...     None
# 2        @marioredondo @cartagadascr @MrHRScr ojala no ...     None
# ...

# %%
place_2016_2 = pd.read_json("../data/tweets_place_2016_2.json")
place_2016_2
# Out:
#                         id                  DateTime  \
# 0       701893032497385472 2016-02-22 22:15:14+00:00
# 1       700112171288518656 2016-02-18 00:18:43+00:00
# 2       692558917671456768 2016-01-28 04:04:47+00:00
# 3       690904190055383040 2016-01-23 14:29:29+00:00
# 4       671734874982645760 2015-12-01 16:57:29+00:00
# ...                    ...                       ...
# 685305  649561090288824320 2015-10-01 12:26:46+00:00
# 685306  649560950614290432 2015-10-01 12:26:13+00:00
# 685307  649377793252311040 2015-10-01 00:18:25+00:00
# 685308  649377721554857984 2015-10-01 00:18:08+00:00
# 685309  649375581256060928 2015-10-01 00:09:38+00:00
#
#                                             tweet_content cashtags  \
# 0                                  @jamesdrodriguez hola!     None
# 1                                 https://t.co/L2HLqDihV5     None
# 2                  @Louis_Tomlinson  the best photo ever!     None
# ...

# %%
place_2016_3 = pd.read_json("../data/tweets_place_2016_3.json")
place_2016_3
# Out:
#                         id                  DateTime  \
# 0       792612904004714496 2016-10-30 06:23:37+00:00
# 1       792612689126318080 2016-10-30 06:22:45+00:00
# 2       792580795777028096 2016-10-30 04:16:01+00:00
# 3       792573506957574144 2016-10-30 03:47:04+00:00
# 4       790227929146003456 2016-10-23 16:26:34+00:00
# ...                    ...                       ...
# 491712  649451432182157312 2015-10-01 05:11:02+00:00
# 491713  649450969663709184 2015-10-01 05:09:12+00:00
# 491714  649449519701168128 2015-10-01 05:03:26+00:00
# 491715  649446550272352256 2015-10-01 04:51:38+00:00
# 491716  649415492223021056 2015-10-01 02:48:13+00:00
#
#                                             tweet_content cashtags  \
# 0                                    @JG_BERROCAL 😂😂😂😂 ok     None
# 1       @JG_BERROCAL se están cayendo unos partiditos ...     None
# 2       @LienaMv dígale a Tarzan que se agarre de este...     None
# ...

# %%
place_2016_list = [place_2016_1, place_2016_2, place_2016_3]

# %%
place_2016 = pd.concat(place_2016_list, ignore_index=True)

# %%
place_2016
# Out:
#                          id                  DateTime  \
# 0        784384243497480192 2016-10-07 13:25:51+00:00
# 1        784383799857602560 2016-10-07 13:24:05+00:00
# 2        784381984541855744 2016-10-07 13:16:52+00:00
# 3        784381773182414848 2016-10-07 13:16:02+00:00
# 4        784379568484261888 2016-10-07 13:07:16+00:00
# ...                     ...                       ...
# 2224266  649451432182157312 2015-10-01 05:11:02+00:00
# 2224267  649450969663709184 2015-10-01 05:09:12+00:00
# 2224268  649449519701168128 2015-10-01 05:03:26+00:00
# 2224269  649446550272352256 2015-10-01 04:51:38+00:00
# 2224270  649415492223021056 2015-10-01 02:48:13+00:00
#
#                                              tweet_content cashtags  \
# 0        @cartagadascr @marioredondo @MrHRScr lo que es...     None
# 1        @MrHRScr @marioredondo @cartagadascr yo la con...     None
# 2        @marioredondo @cartagadascr @MrHRScr ojala no ...     None
# ...

# %%
place_2016.columns
# Out:
# Index(['id', 'DateTime', 'tweet_content', 'cashtags', 'coordinates',
#        'hashtags', 'lang', 'like_count', 'media', 'mentioned_users', 'place',
#        'quoteCount', 'quotedTweet', 'renderedContent', 'replyCount',
#        'retweetCount', 'retweetedTweet', 'source', 'username', 'user_location',
#        'user_id', 'user_displayname', 'user_description',
#        'user_description_urls', 'user_verified', 'user_created',
#        'user_followers_count', 'user_friends_count', 'user_statuses_count',
#        'user_favourites_count', 'user_listed_count', 'user_media_count',
#        'user_protected', 'user_link_url', 'user_link_tcourl',
#        'user_profile_image_url', 'user_profile_banner_url', 'user_label'],
#       dtype='object')

# %%
place_2016.place.unique()
# Out:
# None                                                        1614650
# Coordinates(longitude=-84.0791779, latitude=9.4674778)       127002
# Coordinates(longitude=-85.3044586, latitude=8.0379929)        93091
# Coordinates(longitude=-85.4422302, latitude=9.8233318)        30777
# Coordinates(longitude=-84.851172, latitude=9.9700296)         30498
#                                                              ...
# Coordinates(longitude=-83.90846301, latitude=9.84613215)          1
# Coordinates(longitude=-83.92467281, latitude=9.84312823)          1
# Coordinates(longitude=-83.81422274, latitude=9.834774)            1
# Coordinates(longitude=-84.09803, latitude=9.957927)               1
# Coordinates(longitude=-84.4328804, latitude=10.3303769)           1
# Name: coordinates, Length: 35602, dtype: int64

# %%
place_2016[place_2016.place != "None"]
# Out:
#                          id                  DateTime  \
# 10       701548252059951104 2016-02-21 23:25:12+00:00
# 11       688885537252376576 2016-01-18 00:48:05+00:00
# 12       682058338494844928 2015-12-30 04:39:14+00:00
# 13       679709526954610688 2015-12-23 17:05:54+00:00
# 14       677197340063625216 2015-12-16 18:43:22+00:00
# ...                     ...                       ...
# 2222661  673406219974000640 2015-12-06 07:38:48+00:00
# 2222903  670790269676224512 2015-11-29 02:23:57+00:00
# 2223028  668927965292568576 2015-11-23 23:03:49+00:00
# 2223495  663527500178419712 2015-11-09 01:24:18+00:00
# 2223573  662301463037804544 2015-11-05 16:12:28+00:00
#
#                                              tweet_content cashtags  \
# 10       @BancoPopularCR con @_msln_  por supuesto! !! ...     None
# 11                                          Que buen meneo     None
# 12          @_msln _ me extraña que usted pregunte eso!!!!     None
# ...

# %%
location_2016[location_2016.place != "None"]
# Out:
#                         id                  DateTime  \
# 0       730389934725435392 2016-05-11 13:31:45+00:00
# 1       660279130944966656 2015-10-31 02:16:26+00:00
# 21      676122083257147392 2015-12-13 19:30:41+00:00
# 22      674790398557069312 2015-12-10 03:19:02+00:00
# 27      667193736544276480 2015-11-19 04:12:37+00:00
# ...                    ...                       ...
# 374542  709104870352093184 2016-03-13 19:52:30+00:00
# 375683  698826654190280704 2016-02-14 11:10:32+00:00
# 375689  698818696433819648 2016-02-14 10:38:55+00:00
# 376530  693928578203938816 2016-01-31 22:47:20+00:00
# 377769  687142322803490816 2016-01-13 05:21:10+00:00
#
#                                             tweet_content cashtags  \
# 0              @PLNSanisidro @lissvil @plncr @JuventudPLN     None
# 1                                Confie en la experiencia     None
# 21      Adhiero a @germanfermo, urge rendición de cuen...     None
# ...

# %% [markdown]
# 608630 + 101388 = 710018 raw tweets from 2016 with coordinates

# %%
import pandas as pd

location_2019 = pd.read_json("../data/tweets_location_2019.json")
location_2019
# Out:
#                         id                  DateTime  \
# 0       791409464498872320 2016-10-26 22:41:34+00:00
# 1       791242642956906496 2016-10-26 11:38:41+00:00
# 2       791041941244899328 2016-10-25 22:21:10+00:00
# 3       791033266560262144 2016-10-25 21:46:42+00:00
# 4       785107012652769280 2016-10-09 13:17:53+00:00
# ...                    ...                       ...
# 146832  649582930189156352 2015-10-01 13:53:33+00:00
# 146833  649561708587954176 2015-10-01 12:29:14+00:00
# 146834  649446900601483264 2015-10-01 04:53:01+00:00
# 146835  649435258853527552 2015-10-01 04:06:46+00:00
# 146836  649434917596631040 2015-10-01 04:05:24+00:00
#
#                                             tweet_content cashtags  \
# 0       Mercidísima citación. Está jugando en gran niv...     None
# 1                                    Pasocristredentormza     None
# 2       Estoy tratando de c omprar entradas para Pales...     None
# ...

# %%
import pandas as pd

place_2019 = pd.read_json("../data/tweets_place_2019.json")
place_2019
# Out:
#                         id                  DateTime  \
# 0       787380528114573312 2016-10-15 19:52:01+00:00
# 1       785321908061384704 2016-10-10 03:31:48+00:00
# 2       767050757195509760 2016-08-20 17:28:46+00:00
# 3       767049552335507456 2016-08-20 17:23:59+00:00
# 4       767048467889946624 2016-08-20 17:19:40+00:00
# ...                    ...                       ...
# 543749  649408674499182592 2015-10-01 02:21:08+00:00
# 543750  649408440582860800 2015-10-01 02:20:12+00:00
# 543751  649408215294214144 2015-10-01 02:19:18+00:00
# 543752  649380691898073088 2015-10-01 00:29:56+00:00
# 543753  649380624143224832 2015-10-01 00:29:40+00:00
#
#                                             tweet_content cashtags  \
# 0                      Hoy se patina.😏\n\n#puertopatín.😏🔥     None
# 1                                         Tengo hambre.🐷💔     None
# 2             @SolanoRoberto04  mae era para ir a esparza     None
# ...

# %%
location_2019[location_2019.place != "None"]
# Out:
#                         id                  DateTime  \
# 0       791409464498872320 2016-10-26 22:41:34+00:00
# 5       777712540952489984 2016-09-19 03:34:53+00:00
# 6       777712323028979712 2016-09-19 03:34:01+00:00
# 14      663262679205855232 2015-11-08 07:52:00+00:00
# 15      662419561736765440 2015-11-06 00:01:45+00:00
# ...                    ...                       ...
# 146831  649643897006592000 2015-10-01 17:55:49+00:00
# 146832  649582930189156352 2015-10-01 13:53:33+00:00
# 146833  649561708587954176 2015-10-01 12:29:14+00:00
# 146835  649435258853527552 2015-10-01 04:06:46+00:00
# 146836  649434917596631040 2015-10-01 04:05:24+00:00
#
#                                             tweet_content cashtags  \
# 0       Mercidísima citación. Está jugando en gran niv...     None
# 5       Just posted a photo @ Adrogue City https://t.c...     None
# 6       Just posted a photo @ Adrogue City https://t.c...     None
# ...

# %%
place_2019[place_2019.place != "None"]
# Out:
#                         id                  DateTime  \
# 8       708852855852040192 2016-03-13 03:11:05+00:00
# 63      728602831796604928 2016-05-06 15:10:26+00:00
# 64      728037257236512768 2016-05-05 01:43:03+00:00
# 71      770242871832313856 2016-08-29 12:53:05+00:00
# 76      681204132229812224 2015-12-27 20:04:55+00:00
# ...                    ...                       ...
# 543748  649408777578373120 2015-10-01 02:21:32+00:00
# 543750  649408440582860800 2015-10-01 02:20:12+00:00
# 543751  649408215294214144 2015-10-01 02:19:18+00:00
# 543752  649380691898073088 2015-10-01 00:29:56+00:00
# 543753  649380624143224832 2015-10-01 00:29:40+00:00
#
#                                             tweet_content cashtags  \
# 8       Feliz de tener la oportunidad de brindar un cu...     None
# 63      Pre-ventas para **Wet Dream** 14.5.16 https://...     None
# 64            Clasico + parcito 🔥 https://t.co/Fyk4lT1hn3     None
# ...

# %% [markdown]
# 25894 + 137283 = 163177 raw tweets with coordinates from 2019

# %%
25894 + 137283
# Out:
# 163177
